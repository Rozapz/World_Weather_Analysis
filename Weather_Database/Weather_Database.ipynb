# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 780

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_Weather_descr = city_weather["weather"][0]["description"]

        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "weather description": city_Weather_descr})  
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | melilla
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | ponta do sol
# Processing Record 4 of Set 1 | yenagoa
# Processing Record 5 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 1 | harper
# Processing Record 7 of Set 1 | codrington
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | kharp
# Processing Record 10 of Set 1 | cadillac
# Processing Record 11 of Set 1 | mar del plata
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | kieta
# Processing Record 14 of Set 1 | atar
# Processing Record 15 of Set 1 | butaritari
# Processing Record 16 of Set 1 | vila
# Processing Record 17 of Set 1 | neiafu
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | marzuq
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | victoria
# Processing Record 22 of Set 1 | tias
# Processing Record 23 of Set 1 | henties bay
# Processing Record 24 of Set 1 | newtownards
# Processing Record 25 of Set 1 | saint george
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | port elizabeth
# Processing Record 28 of Set 1 | muros
# Processing Record 29 of Set 1 | chuy
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | bluff
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | tasiilaq
# Processing Record 34 of Set 1 | maneadero
# Processing Record 35 of Set 1 | upernavik
# Processing Record 36 of Set 1 | banjar
# Processing Record 37 of Set 1 | erie
# Processing Record 38 of Set 1 | faya
# Processing Record 39 of Set 1 | te anau
# Processing Record 40 of Set 1 | dunedin
# Processing Record 41 of Set 1 | lagoa
# Processing Record 42 of Set 1 | mendahara
# City not found. Skipping...
# Processing Record 43 of Set 1 | reyes
# Processing Record 44 of Set 1 | georgetown
# Processing Record 45 of Set 1 | schipluiden
# Processing Record 46 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 47 of Set 1 | hobart
# Processing Record 48 of Set 1 | avarua
# Processing Record 49 of Set 1 | sao filipe
# Processing Record 50 of Set 1 | vaini
# Processing Record 1 of Set 2 | kuminskiy
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | longyearbyen
# Processing Record 4 of Set 2 | constitucion
# Processing Record 5 of Set 2 | busselton
# Processing Record 6 of Set 2 | fortuna
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | ilulissat
# Processing Record 9 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 2 | yumen
# Processing Record 11 of Set 2 | portland
# Processing Record 12 of Set 2 | new norfolk
# Processing Record 13 of Set 2 | tessalit
# Processing Record 14 of Set 2 | saint-joseph
# Processing Record 15 of Set 2 | eureka
# Processing Record 16 of Set 2 | vostok
# Processing Record 17 of Set 2 | kaitangata
# Processing Record 18 of Set 2 | cape town
# Processing Record 19 of Set 2 | hithadhoo
# Processing Record 20 of Set 2 | verkhnevilyuysk
# Processing Record 21 of Set 2 | san
# Processing Record 22 of Set 2 | zmeinogorsk
# Processing Record 23 of Set 2 | luau
# Processing Record 24 of Set 2 | asau
# Processing Record 25 of Set 2 | alyangula
# Processing Record 26 of Set 2 | tigil
# Processing Record 27 of Set 2 | cockburn town
# Processing Record 28 of Set 2 | arraial do cabo
# Processing Record 29 of Set 2 | roald
# Processing Record 30 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 31 of Set 2 | jamestown
# Processing Record 32 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 2 | mukhen
# Processing Record 34 of Set 2 | huarmey
# Processing Record 35 of Set 2 | vondrozo
# Processing Record 36 of Set 2 | samarinda
# Processing Record 37 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 2 | kapaa
# Processing Record 39 of Set 2 | saskylakh
# Processing Record 40 of Set 2 | airai
# Processing Record 41 of Set 2 | petatlan
# Processing Record 42 of Set 2 | dikson
# Processing Record 43 of Set 2 | kalmunai
# Processing Record 44 of Set 2 | mahebourg
# Processing Record 45 of Set 2 | kodiak
# Processing Record 46 of Set 2 | cairns
# Processing Record 47 of Set 2 | coquimbo
# Processing Record 48 of Set 2 | warwick
# Processing Record 49 of Set 2 | grindavik
# Processing Record 50 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 3 | riyadh
# Processing Record 2 of Set 3 | erenhot
# Processing Record 3 of Set 3 | mehran
# Processing Record 4 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 3 | gambela
# Processing Record 6 of Set 3 | castro
# Processing Record 7 of Set 3 | bengkulu
# Processing Record 8 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 3 | tuatapere
# Processing Record 10 of Set 3 | mentok
# City not found. Skipping...
# Processing Record 11 of Set 3 | alexandria
# Processing Record 12 of Set 3 | guaraniacu
# Processing Record 13 of Set 3 | rocha
# Processing Record 14 of Set 3 | barrow
# Processing Record 15 of Set 3 | bambous virieux
# Processing Record 16 of Set 3 | ratnagiri
# Processing Record 17 of Set 3 | clyde river
# Processing Record 18 of Set 3 | beringovskiy
# Processing Record 19 of Set 3 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 3 | lahad datu
# Processing Record 21 of Set 3 | touho
# Processing Record 22 of Set 3 | kavieng
# Processing Record 23 of Set 3 | lebu
# Processing Record 24 of Set 3 | nyrob
# Processing Record 25 of Set 3 | broome
# Processing Record 26 of Set 3 | rumphi
# Processing Record 27 of Set 3 | broken hill
# Processing Record 28 of Set 3 | muskegon heights
# Processing Record 29 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 3 | balagansk
# Processing Record 31 of Set 3 | pervomayskiy
# Processing Record 32 of Set 3 | punta arenas
# Processing Record 33 of Set 3 | toms river
# Processing Record 34 of Set 3 | orgun
# City not found. Skipping...
# Processing Record 35 of Set 3 | vsetin
# Processing Record 36 of Set 3 | cherskiy
# Processing Record 37 of Set 3 | santa ines
# Processing Record 38 of Set 3 | north guwahati
# Processing Record 39 of Set 3 | khatanga
# Processing Record 40 of Set 3 | safakulevo
# Processing Record 41 of Set 3 | olden
# Processing Record 42 of Set 3 | moranbah
# Processing Record 43 of Set 3 | meulaboh
# Processing Record 44 of Set 3 | igrim
# Processing Record 45 of Set 3 | padang
# Processing Record 46 of Set 3 | tuktoyaktuk
# Processing Record 47 of Set 3 | hannibal
# Processing Record 48 of Set 3 | marawi
# Processing Record 49 of Set 3 | severo-kurilsk
# Processing Record 50 of Set 3 | logatec
# Processing Record 1 of Set 4 | varna
# Processing Record 2 of Set 4 | lagoa nova
# Processing Record 3 of Set 4 | ndele
# Processing Record 4 of Set 4 | banda aceh
# Processing Record 5 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 4 | bethel
# Processing Record 7 of Set 4 | staronizhestebliyevskaya
# Processing Record 8 of Set 4 | sitka
# Processing Record 9 of Set 4 | geraldton
# Processing Record 10 of Set 4 | itoman
# Processing Record 11 of Set 4 | sinnamary
# Processing Record 12 of Set 4 | guayaramerin
# Processing Record 13 of Set 4 | ahipara
# Processing Record 14 of Set 4 | killam
# Processing Record 15 of Set 4 | matara
# Processing Record 16 of Set 4 | kouango
# Processing Record 17 of Set 4 | anadyr
# Processing Record 18 of Set 4 | mayo
# Processing Record 19 of Set 4 | provideniya
# Processing Record 20 of Set 4 | samarai
# Processing Record 21 of Set 4 | oktyabrskiy
# Processing Record 22 of Set 4 | do rud
# City not found. Skipping...
# Processing Record 23 of Set 4 | dali
# Processing Record 24 of Set 4 | santiago del estero
# Processing Record 25 of Set 4 | mancio lima
# Processing Record 26 of Set 4 | wanning
# Processing Record 27 of Set 4 | san patricio
# Processing Record 28 of Set 4 | skibbereen
# Processing Record 29 of Set 4 | peniche
# Processing Record 30 of Set 4 | hoquiam
# Processing Record 31 of Set 4 | sarakhs
# Processing Record 32 of Set 4 | muravlenko
# Processing Record 33 of Set 4 | poum
# Processing Record 34 of Set 4 | grand-santi
# Processing Record 35 of Set 4 | xining
# Processing Record 36 of Set 4 | pangnirtung
# Processing Record 37 of Set 4 | port lincoln
# Processing Record 38 of Set 4 | biak
# Processing Record 39 of Set 4 | pokhara
# Processing Record 40 of Set 4 | kloulklubed
# Processing Record 41 of Set 4 | bandarbeyla
# Processing Record 42 of Set 4 | ubauro
# Processing Record 43 of Set 4 | shipitsyno
# Processing Record 44 of Set 4 | meinung
# City not found. Skipping...
# Processing Record 45 of Set 4 | kasongo-lunda
# Processing Record 46 of Set 4 | formosa do rio preto
# Processing Record 47 of Set 4 | lata
# Processing Record 48 of Set 4 | prince rupert
# Processing Record 49 of Set 4 | carbonia
# Processing Record 50 of Set 4 | north bend
# Processing Record 1 of Set 5 | leninskoye
# Processing Record 2 of Set 5 | bredasdorp
# Processing Record 3 of Set 5 | iqaluit
# Processing Record 4 of Set 5 | contamana
# Processing Record 5 of Set 5 | peterhead
# Processing Record 6 of Set 5 | moron
# Processing Record 7 of Set 5 | puerto madero
# Processing Record 8 of Set 5 | papagaios
# Processing Record 9 of Set 5 | pleasanton
# Processing Record 10 of Set 5 | san quintin
# Processing Record 11 of Set 5 | carnarvon
# Processing Record 12 of Set 5 | iquitos
# Processing Record 13 of Set 5 | buraydah
# Processing Record 14 of Set 5 | lavrentiya
# Processing Record 15 of Set 5 | lagdo
# Processing Record 16 of Set 5 | moerai
# Processing Record 17 of Set 5 | boyolangu
# Processing Record 18 of Set 5 | flinders
# Processing Record 19 of Set 5 | mayumba
# Processing Record 20 of Set 5 | aldan
# Processing Record 21 of Set 5 | albany
# Processing Record 22 of Set 5 | sao gabriel da cachoeira
# Processing Record 23 of Set 5 | novo mesto
# Processing Record 24 of Set 5 | karasburg
# Processing Record 25 of Set 5 | tidore
# City not found. Skipping...
# Processing Record 26 of Set 5 | encheng
# Processing Record 27 of Set 5 | shumskiy
# Processing Record 28 of Set 5 | alugan
# Processing Record 29 of Set 5 | asfi
# Processing Record 30 of Set 5 | korla
# Processing Record 31 of Set 5 | charagua
# Processing Record 32 of Set 5 | luderitz
# Processing Record 33 of Set 5 | linqing
# Processing Record 34 of Set 5 | sao felix do xingu
# Processing Record 35 of Set 5 | klaksvik
# Processing Record 36 of Set 5 | namie
# Processing Record 37 of Set 5 | mount isa
# Processing Record 38 of Set 5 | hasaki
# Processing Record 39 of Set 5 | nsanje
# Processing Record 40 of Set 5 | hay river
# Processing Record 41 of Set 5 | belyy yar
# Processing Record 42 of Set 5 | wattegama
# Processing Record 43 of Set 5 | ostrovnoy
# Processing Record 44 of Set 5 | nuuk
# Processing Record 45 of Set 5 | ribeira grande
# Processing Record 46 of Set 5 | guerrero negro
# Processing Record 47 of Set 5 | urdzhar
# City not found. Skipping...
# Processing Record 48 of Set 5 | angoram
# Processing Record 49 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 50 of Set 5 | shingu
# Processing Record 1 of Set 6 | bababe
# City not found. Skipping...
# Processing Record 2 of Set 6 | east london
# Processing Record 3 of Set 6 | sobolevo
# Processing Record 4 of Set 6 | rongcheng
# Processing Record 5 of Set 6 | kenai
# Processing Record 6 of Set 6 | baoshan
# Processing Record 7 of Set 6 | planeta rica
# Processing Record 8 of Set 6 | lyubymivka
# Processing Record 9 of Set 6 | sao bento do sul
# Processing Record 10 of Set 6 | narsaq
# Processing Record 11 of Set 6 | shahr-e babak
# Processing Record 12 of Set 6 | churapcha
# Processing Record 13 of Set 6 | saint-pierre
# Processing Record 14 of Set 6 | tiznit
# Processing Record 15 of Set 6 | ahuimanu
# Processing Record 16 of Set 6 | kachikau
# City not found. Skipping...
# Processing Record 17 of Set 6 | polovinnoye
# Processing Record 18 of Set 6 | abha
# Processing Record 19 of Set 6 | sebina
# Processing Record 20 of Set 6 | suntar
# Processing Record 21 of Set 6 | cap malheureux
# Processing Record 22 of Set 6 | hobara
# Processing Record 23 of Set 6 | tateyama
# Processing Record 24 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 6 | general roca
# Processing Record 26 of Set 6 | la paz
# Processing Record 27 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 6 | alofi
# Processing Record 29 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 30 of Set 6 | torbay
# Processing Record 31 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 32 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 33 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 34 of Set 6 | coos bay
# Processing Record 35 of Set 6 | loukhi
# Processing Record 36 of Set 6 | chokurdakh
# Processing Record 37 of Set 6 | irbil
# Processing Record 38 of Set 6 | yerbogachen
# Processing Record 39 of Set 6 | saint-philippe
# Processing Record 40 of Set 6 | teluknaga
# Processing Record 41 of Set 6 | kitakata
# Processing Record 42 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 6 | arlit
# Processing Record 44 of Set 6 | san lorenzo
# Processing Record 45 of Set 6 | chara
# Processing Record 46 of Set 6 | mehamn
# Processing Record 47 of Set 6 | cidreira
# Processing Record 48 of Set 6 | ucluelet
# Processing Record 49 of Set 6 | taltal
# Processing Record 50 of Set 6 | kijang
# Processing Record 1 of Set 7 | port blair
# Processing Record 2 of Set 7 | sao joao da barra
# Processing Record 3 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 7 | fushun
# Processing Record 5 of Set 7 | coihaique
# Processing Record 6 of Set 7 | coahuayana
# Processing Record 7 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 8 of Set 7 | nikolskoye
# Processing Record 9 of Set 7 | bayji
# Processing Record 10 of Set 7 | port hardy
# Processing Record 11 of Set 7 | raahe
# Processing Record 12 of Set 7 | esna
# Processing Record 13 of Set 7 | kawana waters
# City not found. Skipping...
# Processing Record 14 of Set 7 | rosario
# Processing Record 15 of Set 7 | cananeia
# Processing Record 16 of Set 7 | pinerolo
# Processing Record 17 of Set 7 | novikovo
# Processing Record 18 of Set 7 | thompson
# Processing Record 19 of Set 7 | ravar
# Processing Record 20 of Set 7 | namatanai
# Processing Record 21 of Set 7 | vila franca do campo
# Processing Record 22 of Set 7 | kununurra
# Processing Record 23 of Set 7 | mandalgovi
# Processing Record 24 of Set 7 | sovetskiy
# Processing Record 25 of Set 7 | puerto del rosario
# Processing Record 26 of Set 7 | leningradskiy
# Processing Record 27 of Set 7 | bathsheba
# Processing Record 28 of Set 7 | namibe
# Processing Record 29 of Set 7 | sosnogorsk
# Processing Record 30 of Set 7 | svetlyy
# Processing Record 31 of Set 7 | faanui
# Processing Record 32 of Set 7 | katsuura
# Processing Record 33 of Set 7 | jashpurnagar
# Processing Record 34 of Set 7 | mackenzie
# Processing Record 35 of Set 7 | sosua
# Processing Record 36 of Set 7 | christchurch
# Processing Record 37 of Set 7 | nalut
# Processing Record 38 of Set 7 | estevan
# Processing Record 39 of Set 7 | omboue
# Processing Record 40 of Set 7 | drawsko pomorskie
# Processing Record 41 of Set 7 | chernyshevskiy
# Processing Record 42 of Set 7 | monte santo de minas
# Processing Record 43 of Set 7 | tual
# Processing Record 44 of Set 7 | nelson
# Processing Record 45 of Set 7 | sarmanovo
# Processing Record 46 of Set 7 | victoria point
# Processing Record 47 of Set 7 | champerico
# Processing Record 48 of Set 7 | wexford
# Processing Record 49 of Set 7 | kahului
# Processing Record 50 of Set 7 | bonavista
# Processing Record 1 of Set 8 | zyryanka
# Processing Record 2 of Set 8 | mantua
# Processing Record 3 of Set 8 | nanortalik
# Processing Record 4 of Set 8 | mount darwin
# Processing Record 5 of Set 8 | kavaratti
# Processing Record 6 of Set 8 | khani
# Processing Record 7 of Set 8 | vardo
# Processing Record 8 of Set 8 | nova prata
# Processing Record 9 of Set 8 | zalantun
# Processing Record 10 of Set 8 | ypsonas
# Processing Record 11 of Set 8 | skjervoy
# Processing Record 12 of Set 8 | norman wells
# Processing Record 13 of Set 8 | swan river
# Processing Record 14 of Set 8 | eyl
# Processing Record 15 of Set 8 | kiruna
# Processing Record 16 of Set 8 | gualeguay
# Processing Record 17 of Set 8 | araouane
# Processing Record 18 of Set 8 | maubin
# Processing Record 19 of Set 8 | chipoka
# Processing Record 20 of Set 8 | anaco
# Processing Record 21 of Set 8 | tiksi
# Processing Record 22 of Set 8 | flin flon
# Processing Record 23 of Set 8 | ponta delgada
# Processing Record 24 of Set 8 | along
# Processing Record 25 of Set 8 | gizo
# Processing Record 26 of Set 8 | kiama
# Processing Record 27 of Set 8 | putina
# Processing Record 28 of Set 8 | gimli
# Processing Record 29 of Set 8 | esperance
# Processing Record 30 of Set 8 | souillac
# Processing Record 31 of Set 8 | villa maria
# Processing Record 32 of Set 8 | rodrigues alves
# Processing Record 33 of Set 8 | kokoda
# Processing Record 34 of Set 8 | porto novo
# Processing Record 35 of Set 8 | san cristobal
# Processing Record 36 of Set 8 | paciran
# Processing Record 37 of Set 8 | seoul
# Processing Record 38 of Set 8 | san carlos de bariloche
# Processing Record 39 of Set 8 | labuhan
# Processing Record 40 of Set 8 | koslan
# Processing Record 41 of Set 8 | yeehaw junction
# City not found. Skipping...
# Processing Record 42 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 43 of Set 8 | stykkisholmur
# Processing Record 44 of Set 8 | darhan
# Processing Record 45 of Set 8 | hammerfest
# Processing Record 46 of Set 8 | kropotkin
# Processing Record 47 of Set 8 | yar-sale
# Processing Record 48 of Set 8 | pisco
# Processing Record 49 of Set 8 | inhambane
# Processing Record 50 of Set 8 | kawalu
# Processing Record 1 of Set 9 | doume
# Processing Record 2 of Set 9 | bairiki
# Processing Record 3 of Set 9 | chokwe
# Processing Record 4 of Set 9 | dolbeau
# City not found. Skipping...
# Processing Record 5 of Set 9 | college
# Processing Record 6 of Set 9 | fairhope
# Processing Record 7 of Set 9 | varberg
# Processing Record 8 of Set 9 | acaponeta
# Processing Record 9 of Set 9 | pravdinsk
# Processing Record 10 of Set 9 | misratah
# Processing Record 11 of Set 9 | kaihua
# Processing Record 12 of Set 9 | pogar
# Processing Record 13 of Set 9 | saint-pacome
# City not found. Skipping...
# Processing Record 14 of Set 9 | hamilton
# Processing Record 15 of Set 9 | chumikan
# Processing Record 16 of Set 9 | road town
# Processing Record 17 of Set 9 | srednekolymsk
# Processing Record 18 of Set 9 | karratha
# Processing Record 19 of Set 9 | assiniboia
# Processing Record 20 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 21 of Set 9 | arinos
# Processing Record 22 of Set 9 | kaeo
# Processing Record 23 of Set 9 | nishihara
# Processing Record 24 of Set 9 | tete
# Processing Record 25 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 26 of Set 9 | zhanakorgan
# Processing Record 27 of Set 9 | heihe
# Processing Record 28 of Set 9 | zhob
# Processing Record 29 of Set 9 | talnakh
# Processing Record 30 of Set 9 | van buren
# Processing Record 31 of Set 9 | rock sound
# Processing Record 32 of Set 9 | samoylovka
# Processing Record 33 of Set 9 | ostrovskoye
# Processing Record 34 of Set 9 | nkowakowa
# Processing Record 35 of Set 9 | cedar rapids
# Processing Record 36 of Set 9 | waris aliganj
# Processing Record 37 of Set 9 | sesvete
# Processing Record 38 of Set 9 | nagaur
# Processing Record 39 of Set 9 | griffith
# Processing Record 40 of Set 9 | andselv
# City not found. Skipping...
# Processing Record 41 of Set 9 | tecoanapa
# Processing Record 42 of Set 9 | itumba
# Processing Record 43 of Set 9 | paamiut
# Processing Record 44 of Set 9 | cayenne
# Processing Record 45 of Set 9 | ziway
# Processing Record 46 of Set 9 | honiara
# Processing Record 47 of Set 9 | qasigiannguit
# Processing Record 48 of Set 9 | gaoual
# Processing Record 49 of Set 9 | abu dhabi
# Processing Record 50 of Set 9 | bjornevatn
# Processing Record 1 of Set 10 | todi
# Processing Record 2 of Set 10 | nioaque
# Processing Record 3 of Set 10 | pochutla
# Processing Record 4 of Set 10 | ancud
# Processing Record 5 of Set 10 | kemijarvi
# Processing Record 6 of Set 10 | port-gentil
# Processing Record 7 of Set 10 | chesma
# Processing Record 8 of Set 10 | pasni
# Processing Record 9 of Set 10 | gympie
# Processing Record 10 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 11 of Set 10 | saldanha
# Processing Record 12 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 10 | horqueta
# Processing Record 14 of Set 10 | saint anthony
# Processing Record 15 of Set 10 | trairi
# Processing Record 16 of Set 10 | bossangoa
# Processing Record 17 of Set 10 | baykit
# Processing Record 18 of Set 10 | itarema
# Processing Record 19 of Set 10 | san pedro de ycuamandiyu
# Processing Record 20 of Set 10 | ugoofaaru
# Processing Record 21 of Set 10 | kruisfontein
# Processing Record 22 of Set 10 | marovoay
# Processing Record 23 of Set 10 | ambon
# Processing Record 24 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 10 | aykhal
# Processing Record 26 of Set 10 | kattivakkam
# Processing Record 27 of Set 10 | tomatlan
# Processing Record 28 of Set 10 | sohag
# Processing Record 29 of Set 10 | belaya gora
# Processing Record 30 of Set 10 | hikari
# Processing Record 31 of Set 10 | jutai
# Processing Record 32 of Set 10 | yinchuan
# Processing Record 33 of Set 10 | warragul
# Processing Record 34 of Set 10 | petrolandia
# City not found. Skipping...
# Processing Record 35 of Set 10 | zakharovo
# Processing Record 36 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 37 of Set 10 | havoysund
# Processing Record 38 of Set 10 | ternate
# Processing Record 39 of Set 10 | bouca
# Processing Record 40 of Set 10 | aitape
# Processing Record 41 of Set 10 | taraz
# Processing Record 42 of Set 10 | mitsamiouli
# Processing Record 43 of Set 10 | barcelos
# Processing Record 44 of Set 10 | fuente de oro
# Processing Record 45 of Set 10 | peremyshlyany
# Processing Record 46 of Set 10 | yulara
# Processing Record 47 of Set 10 | beloha
# Processing Record 48 of Set 10 | rovato
# Processing Record 49 of Set 10 | praia da vitoria
# Processing Record 50 of Set 10 | nhulunbuy
# Processing Record 1 of Set 11 | kilindoni
# Processing Record 2 of Set 11 | lompoc
# Processing Record 3 of Set 11 | haines junction
# Processing Record 4 of Set 11 | columbus
# Processing Record 5 of Set 11 | puerto colombia
# Processing Record 6 of Set 11 | fowa
# Processing Record 7 of Set 11 | russell
# Processing Record 8 of Set 11 | la primavera
# Processing Record 9 of Set 11 | tautira
# Processing Record 10 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 11 | riohacha
# Processing Record 12 of Set 11 | del rio
# Processing Record 13 of Set 11 | half moon bay
# Processing Record 14 of Set 11 | kalmar
# Processing Record 15 of Set 11 | margherita
# Processing Record 16 of Set 11 | sussex
# Processing Record 17 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 18 of Set 11 | emerald
# Processing Record 19 of Set 11 | mount gambier
# Processing Record 20 of Set 11 | mercedes
# Processing Record 21 of Set 11 | kaitong
# Processing Record 22 of Set 11 | edgewater
# Processing Record 23 of Set 11 | thung song
# Processing Record 24 of Set 11 | rio brilhante
# Processing Record 25 of Set 11 | tonantins
# Processing Record 26 of Set 11 | cabo san lucas
# Processing Record 27 of Set 11 | puerto leguizamo
# Processing Record 28 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 29 of Set 11 | challapata
# Processing Record 30 of Set 11 | lodja
# Processing Record 31 of Set 11 | ilhabela
# Processing Record 32 of Set 11 | nouadhibou
# Processing Record 33 of Set 11 | mumbwa
# Processing Record 34 of Set 11 | humaita
# Processing Record 35 of Set 11 | laguna
# Processing Record 36 of Set 11 | maningrida
# Processing Record 37 of Set 11 | santa cruz
# Processing Record 38 of Set 11 | matagami
# Processing Record 39 of Set 11 | kupang
# Processing Record 40 of Set 11 | manzhouli
# Processing Record 41 of Set 11 | osmena
# Processing Record 42 of Set 11 | balabac
# Processing Record 43 of Set 11 | kwinana
# Processing Record 44 of Set 11 | noumea
# Processing Record 45 of Set 11 | de-kastri
# Processing Record 46 of Set 11 | abu samrah
# Processing Record 47 of Set 11 | kasongo
# Processing Record 48 of Set 11 | dwarka
# Processing Record 49 of Set 11 | megion
# Processing Record 50 of Set 11 | were ilu
# Processing Record 1 of Set 12 | adeje
# Processing Record 2 of Set 12 | lere
# Processing Record 3 of Set 12 | makakilo city
# Processing Record 4 of Set 12 | aksarka
# Processing Record 5 of Set 12 | glasgow
# Processing Record 6 of Set 12 | kiunga
# Processing Record 7 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 8 of Set 12 | zverinogolovskoye
# Processing Record 9 of Set 12 | nome
# Processing Record 10 of Set 12 | muhos
# Processing Record 11 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 12 of Set 12 | aripuana
# Processing Record 13 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 12 | atbasar
# Processing Record 15 of Set 12 | shimanovsk
# Processing Record 16 of Set 12 | tarnow
# Processing Record 17 of Set 12 | fare
# Processing Record 18 of Set 12 | kautokeino
# Processing Record 19 of Set 12 | lakatoro
# Processing Record 20 of Set 12 | kuhdasht
# Processing Record 21 of Set 12 | ketchikan
# Processing Record 22 of Set 12 | dong hoi
# Processing Record 23 of Set 12 | havre-saint-pierre
# Processing Record 24 of Set 12 | biltine
# Processing Record 25 of Set 12 | pochinki
# Processing Record 26 of Set 12 | coruripe
# Processing Record 27 of Set 12 | zhoucheng
# Processing Record 28 of Set 12 | hambantota
# Processing Record 29 of Set 12 | vao
# Processing Record 30 of Set 12 | kizema
# Processing Record 31 of Set 12 | kirakira
# Processing Record 32 of Set 12 | talcahuano
# Processing Record 33 of Set 12 | cozumel
# Processing Record 34 of Set 12 | blagoveshchensk
# Processing Record 35 of Set 12 | sangar
# Processing Record 36 of Set 12 | phu khieo
# City not found. Skipping...
# Processing Record 37 of Set 12 | medenychi
# Processing Record 38 of Set 12 | opuwo
# Processing Record 39 of Set 12 | tabou
# Processing Record 40 of Set 12 | ibimirim
# Processing Record 41 of Set 12 | komsomolskiy
# Processing Record 42 of Set 12 | oudtshoorn
# Processing Record 43 of Set 12 | slave lake
# Processing Record 44 of Set 12 | thap than
# Processing Record 45 of Set 12 | khandbari
# Processing Record 46 of Set 12 | morondava
# Processing Record 47 of Set 12 | marquette
# Processing Record 48 of Set 12 | talara
# Processing Record 49 of Set 12 | evensk
# Processing Record 50 of Set 12 | belgaum
# Processing Record 1 of Set 13 | dakar
# Processing Record 2 of Set 13 | yatou
# Processing Record 3 of Set 13 | saravan
# Processing Record 4 of Set 13 | kos
# Processing Record 5 of Set 13 | sambava
# Processing Record 6 of Set 13 | alta floresta
# Processing Record 7 of Set 13 | hovd
# Processing Record 8 of Set 13 | nurota
# Processing Record 9 of Set 13 | finschhafen
# Processing Record 10 of Set 13 | barra do garcas
# Processing Record 11 of Set 13 | yanchukan
# City not found. Skipping...
# Processing Record 12 of Set 13 | peleduy
# Processing Record 13 of Set 13 | atlantic city
# Processing Record 14 of Set 13 | talmenka
# Processing Record 15 of Set 13 | roma
# Processing Record 16 of Set 13 | lubartow
# Processing Record 17 of Set 13 | antofagasta
# Processing Record 18 of Set 13 | sorland
# Processing Record 19 of Set 13 | raga
# Processing Record 20 of Set 13 | mogadishu
# Processing Record 21 of Set 13 | sheltozero
# Processing Record 22 of Set 13 | el alto
# Processing Record 23 of Set 13 | oga
# Processing Record 24 of Set 13 | fairbanks
# Processing Record 25 of Set 13 | rio gallegos
# Processing Record 26 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 27 of Set 13 | mtambile
# Processing Record 28 of Set 13 | kindu
# Processing Record 29 of Set 13 | corner brook
# Processing Record 30 of Set 13 | pangai
# Processing Record 31 of Set 13 | saveh
# Processing Record 32 of Set 13 | uspenka
# Processing Record 33 of Set 13 | ariquemes
# Processing Record 34 of Set 13 | banswara
# Processing Record 35 of Set 13 | yagoua
# Processing Record 36 of Set 13 | lorengau
# Processing Record 37 of Set 13 | rorvik
# Processing Record 38 of Set 13 | malindi
# Processing Record 39 of Set 13 | brae
# Processing Record 40 of Set 13 | nabire
# Processing Record 41 of Set 13 | olinda
# Processing Record 42 of Set 13 | patun-an
# City not found. Skipping...
# Processing Record 43 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 13 | safwah
# City not found. Skipping...
# Processing Record 45 of Set 13 | micheweni
# Processing Record 46 of Set 13 | havelock
# Processing Record 47 of Set 13 | praia
# Processing Record 48 of Set 13 | morant bay
# Processing Record 49 of Set 13 | phuthaditjhaba
# Processing Record 50 of Set 13 | sabha
# Processing Record 1 of Set 14 | muisne
# Processing Record 2 of Set 14 | kailua
# Processing Record 3 of Set 14 | maykain
# City not found. Skipping...
# Processing Record 4 of Set 14 | orlik
# Processing Record 5 of Set 14 | oranjestad
# Processing Record 6 of Set 14 | vanavara
# Processing Record 7 of Set 14 | oskarshamn
# Processing Record 8 of Set 14 | saint-louis
# Processing Record 9 of Set 14 | bonthe
# Processing Record 10 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 11 of Set 14 | tevriz
# Processing Record 12 of Set 14 | djambala
# Processing Record 13 of Set 14 | kovvur
# Processing Record 14 of Set 14 | talcher
# Processing Record 15 of Set 14 | hun
# Processing Record 16 of Set 14 | casablanca
# Processing Record 17 of Set 14 | manyana
# Processing Record 18 of Set 14 | buckeye
# Processing Record 19 of Set 14 | naron
# Processing Record 20 of Set 14 | chimbote
# Processing Record 21 of Set 14 | ban chang
# Processing Record 22 of Set 14 | kajaani
# Processing Record 23 of Set 14 | magnor
# Processing Record 24 of Set 14 | shetpe
# Processing Record 25 of Set 14 | yuncheng
# Processing Record 26 of Set 14 | pokaran
# Processing Record 27 of Set 14 | ouadda
# Processing Record 28 of Set 14 | kristiinankaupunki
# Processing Record 29 of Set 14 | margate
# Processing Record 30 of Set 14 | bibiani
# Processing Record 31 of Set 14 | pauini
# Processing Record 32 of Set 14 | kultuk
# Processing Record 33 of Set 14 | okha
# Processing Record 34 of Set 14 | kadykchan
# City not found. Skipping...
# Processing Record 35 of Set 14 | rapid city
# Processing Record 36 of Set 14 | pangkalanbuun
# Processing Record 37 of Set 14 | ossora
# Processing Record 38 of Set 14 | sumbawa
# City not found. Skipping...
# Processing Record 39 of Set 14 | evanston
# Processing Record 40 of Set 14 | port macquarie
# Processing Record 41 of Set 14 | kalisz
# Processing Record 42 of Set 14 | port arthur
# Processing Record 43 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 44 of Set 14 | dovolnoye
# Processing Record 45 of Set 14 | nizhneudinsk
# Processing Record 46 of Set 14 | koutiala
# Processing Record 47 of Set 14 | naze
# Processing Record 48 of Set 14 | pevek
# Processing Record 49 of Set 14 | milingimbi
# City not found. Skipping...
# Processing Record 50 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 1 of Set 15 | makinsk
# Processing Record 2 of Set 15 | acarau
# Processing Record 3 of Set 15 | port keats
# Processing Record 4 of Set 15 | pacific grove
# Processing Record 5 of Set 15 | hofn
# Processing Record 6 of Set 15 | yermakovskoye
# Processing Record 7 of Set 15 | galeana
# Processing Record 8 of Set 15 | karksi-nuia
# Processing Record 9 of Set 15 | durango
# Processing Record 10 of Set 15 | yenangyaung
# Processing Record 11 of Set 15 | tres arroyos
# Processing Record 12 of Set 15 | atasu
# Processing Record 13 of Set 15 | kutum
# Processing Record 14 of Set 15 | higuey
# City not found. Skipping...
# Processing Record 15 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 16 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 17 of Set 15 | axim
# Processing Record 18 of Set 15 | la asuncion
# Processing Record 19 of Set 15 | sur
# Processing Record 20 of Set 15 | goderich
# Processing Record 21 of Set 15 | sibolga
# Processing Record 22 of Set 15 | zwedru
# Processing Record 23 of Set 15 | isangel
# Processing Record 24 of Set 15 | narasannapeta
# Processing Record 25 of Set 15 | batangafo
# Processing Record 26 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 27 of Set 15 | bocaranga
# City not found. Skipping...
# Processing Record 28 of Set 15 | burica
# City not found. Skipping...
# Processing Record 29 of Set 15 | floro
# Processing Record 30 of Set 15 | ilebo
# Processing Record 31 of Set 15 | kudahuvadhoo
# Processing Record 32 of Set 15 | trezzano sul naviglio
# Processing Record 33 of Set 15 | kuloy
# Processing Record 34 of Set 15 | sapernoye
# Processing Record 35 of Set 15 | vega de alatorre
# Processing Record 36 of Set 15 | lamar
# Processing Record 37 of Set 15 | banapur
# Processing Record 38 of Set 15 | san buenaventura
# Processing Record 39 of Set 15 | uyemskiy
# Processing Record 40 of Set 15 | warrington
# Processing Record 41 of Set 15 | robore
# Processing Record 42 of Set 15 | mecca
# Processing Record 43 of Set 15 | nemuro
# Processing Record 44 of Set 15 | playas
# Processing Record 45 of Set 15 | edirne
# Processing Record 46 of Set 15 | caravelas
# Processing Record 47 of Set 15 | iisalmi
# Processing Record 48 of Set 15 | rundu
# Processing Record 49 of Set 15 | kedrovyy
# Processing Record 50 of Set 15 | zaraysk
# Processing Record 1 of Set 16 | egvekinot
# Processing Record 2 of Set 16 | amga
# Processing Record 3 of Set 16 | humberto de campos
# Processing Record 4 of Set 16 | satitoa
# City not found. Skipping...
# Processing Record 5 of Set 16 | ulundi
# Processing Record 6 of Set 16 | conceicao do araguaia
# Processing Record 7 of Set 16 | avera
# Processing Record 8 of Set 16 | calvinia
# Processing Record 9 of Set 16 | barbar
# City not found. Skipping...
# Processing Record 10 of Set 16 | hobyo
# Processing Record 11 of Set 16 | kaolack
# Processing Record 12 of Set 16 | hit
# Processing Record 13 of Set 16 | zhigansk
# Processing Record 14 of Set 16 | saint-augustin
# Processing Record 15 of Set 16 | hailey
# Processing Record 16 of Set 16 | copiapo
# Processing Record 17 of Set 16 | pitimbu
# Processing Record 18 of Set 16 | kholodnyy
# Processing Record 19 of Set 16 | tulun
# Processing Record 20 of Set 16 | olafsvik
# Processing Record 21 of Set 16 | hazorasp
# Processing Record 22 of Set 16 | esmeraldas
# Processing Record 23 of Set 16 | bonfim
# Processing Record 24 of Set 16 | verkhnyaya inta
# Processing Record 25 of Set 16 | marinette
# Processing Record 26 of Set 16 | galiwinku
# City not found. Skipping...
# Processing Record 27 of Set 16 | westport
# Processing Record 28 of Set 16 | tasbuget
# City not found. Skipping...
# Processing Record 29 of Set 16 | ngunguru
# Processing Record 30 of Set 16 | port augusta
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 708

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Melilla  35.2937   -2.9383     61.00        41           0
# 1        Rikitea -23.1203 -134.9692     76.87        71         100
# 2   Ponta Do Sol  32.6667  -17.1000     65.12        55          73
# 3        Yenagoa   4.9247    6.2642     98.28        26         100
# 4         Harper   4.3750   -7.7169     85.08        66          46
# 5     Codrington -38.2667  141.9667     57.27        68         100
# 6   Puerto Ayora  -0.7393  -90.3518     76.96        92          51
# 7          Kharp  66.8014   65.8081      4.35        93          15
# 8       Cadillac  44.2519  -85.4012     31.91       100         100
# 9  Mar Del Plata -38.0023  -57.5575     83.82        81          40
#
#    Wind Speed Country weather description
# 0       17.27      ES           clear sky
# 1        0.85      PF     overcast clouds
# 2        8.05      PT       broken clouds
# 3        2.06      NG     overcast clouds
# 4       10.85      LR    scattered clouds
# 5       11.79      AU     overcast clouds
# 6        1.01      EC       broken clouds
# 7        5.61      RU          few clouds
# 8        9.22      US                snow
# 9       18.99      AR    scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'weather description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
Columns="City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "weather description"

# Recreate the DataFrame by using the new column order
city_data_reorder=city_data_df.reindex(columns=Columns)

# Display sample data
city_data_reorder.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Melilla      ES  35.2937   -2.9383     61.00        41           0
# 1        Rikitea      PF -23.1203 -134.9692     76.87        71         100
# 2   Ponta Do Sol      PT  32.6667  -17.1000     65.12        55          73
# 3        Yenagoa      NG   4.9247    6.2642     98.28        26         100
# 4         Harper      LR   4.3750   -7.7169     85.08        66          46
# 5     Codrington      AU -38.2667  141.9667     57.27        68         100
# 6   Puerto Ayora      EC  -0.7393  -90.3518     76.96        92          51
# 7          Kharp      RU  66.8014   65.8081      4.35        93          15
# 8       Cadillac      US  44.2519  -85.4012     31.91       100         100
# 9  Mar Del Plata      AR -38.0023  -57.5575     83.82        81          40
#
#    Wind Speed weather description
# 0       17.27           clear sky
# 1        0.85     overcast clouds
# 2        8.05       broken clouds
# 3        2.06     overcast clouds
# 4       10.85    scattered clouds
# 5       11.79     overcast clouds
# 6        1.01       broken clouds
# 7        5.61          few clouds
# 8        9.22                snow
# 9       18.99    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_reorder.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# weather description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_vacation.csv"

# Export the city_data DataFrame into a CSV file
city_data_reorder.to_csv(output_data_file, index_label="City_ID")
